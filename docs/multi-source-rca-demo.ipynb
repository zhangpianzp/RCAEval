# %% [markdown]
# # Using RCAEval benchmark to perform RCA using multi-source telemetry data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from RCAEval.utility import download_multi_source_sample
from sklearn.preprocessing import StandardScaler, RobustScaler

from RCAEval.io.time_series import (
    convert_mem_mb,
    drop_constant,
    drop_extra,
    drop_near_constant,
    drop_time,
    preprocess,
    select_useful_cols,
)

from RCAEval.e2e import mmbaro

# %% [markdown]
# ## Prepare data
#
# 1. Download a sample multi-source data
# 2. Inspect data

# %%
# download a sample of multi-source data
download_multi_source_sample()

# %%
# read data 
metrics = pd.read_csv("data/multi-source-data/metrics.csv")
logs = pd.read_csv("data/multi-source-data/logs.csv")
traces = pd.read_csv("data/multi-source-data/traces.csv")

# time series transformed from parsed logs
log_ts = pd.read_csv("data/multi-source-data/logts.csv")

# time series transformed from parsed traces latency and response code
trace_ts_lat = pd.read_csv("data/multi-source-data/tracets_lat.csv")
trace_ts_err = pd.read_csv("data/multi-source-data/tracets_err.csv")

with open("data/multi-source-data/inject_time.txt") as ref:
    inject_time = int(ref.read().strip())

# %%
# inspect data
metrics.head()
# Out:
#          time  adservice_cpu  cartservice_cpu  checkoutservice_cpu  \
# 0  1705353846       0.685023         2.216467             0.215886
# 1  1705353847       0.685023         2.216467             0.380058
# 2  1705353848       0.582707         2.216467             0.380058
# 3  1705353849       0.625903         2.216467             0.380058
# 4  1705353850       0.613414         2.216467             0.380058
#
#    currencyservice_cpu  emailservice_cpu  frontend_cpu  paymentservice_cpu  \
# 0            19.035876          0.279166      6.724489             0.52931
# 1            19.035876          0.279166      6.724489             0.52931
# 2            19.035876          0.279166      6.724489             0.52931
# 3            19.106596          0.279166      6.724489             0.52931
# 4            19.106596          0.279166      5.572668             0.52931
#
#    productcatalogservice_cpu  recommendationservice_cpu  ...  \
# 0                   2.636831                   2.474853  ...
# 1                   2.636858                   2.474853  ...
# 2                   2.584059                   2.474853  ...
# 3                   3.250317                   2.474853  ...
# 4                   3.250317                   2.474853  ...
#
#    adservice_latency-90  cartservice_latency-90  checkoutservice_latency-90  \
# 0              0.004604                0.004993                    0.850000
# 1              0.004594                0.006015                    0.899999
# 2              0.004594                0.006015                    0.899999
# 3              0.004594                0.006015                    0.899999
# 4              0.004594                0.006304                    0.899999
#
#    currencyservice_latency-90  emailservice_latency-90  frontend_latency-90  \
# 0                    0.110638                   0.0046             0.819737
# 1                    0.099482                   0.0046             0.823697
# 2                    0.099482                   0.0046             0.823697
# 3                    0.099482                   0.0046             0.814381
# 4                    0.099482                   0.0046             0.814381
#
#    paymentservice_latency-90  productcatalogservice_latency-90  \
# 0                   0.008955                          0.004418
# 1                   0.008955                          0.004423
# 2                   0.008636                          0.004423
# 3                   0.008636                          0.004416
# 4                   0.008636                          0.004416
#
#    recommendationservice_latency-90  shippingservice_latency-90
# 0                          0.009670                    0.004576
# 1                          0.009672                    0.004576
# 2                          0.009672                    0.004576
# 3                          0.009672                    0.004576
# 4                          0.009672                    0.004576
#
# [5 rows x 73 columns]

# %%
logs.head()
# Out:
#     time            timestamp   container_name                        message  \
# 0  21:24  1705353846067349596  currencyservice  conversion request successful
# 1  21:24  1705353846071454981  currencyservice  conversion request successful
# 2  21:24  1705353846073524861         frontend                request started
# 3  21:24  1705353846073599282         frontend           serving product page
# 4  21:24  1705353846074646435  currencyservice  conversion request successful
#
#    level             req_path  error  cluster_id  \
# 0   info                  NaN    NaN         1.0
# 1   info                  NaN    NaN         1.0
# 2  debug  /product/6E92ZMYYFZ    NaN         2.0
# 3  debug  /product/6E92ZMYYFZ    NaN         3.0
# 4   info                  NaN    NaN         1.0
#
#                                     log_template
# 0  currencyservice conversion request successful
# 1  currencyservice conversion request successful
# 2                       frontend request started
# 3                  frontend serving product page
# 4  currencyservice conversion request successful

# %%
traces.head()
# Out:
#     time                           traceID            spanID      serviceName  \
# 0  21:24  46d5d1e1fc25a09db4a81d4d105cee3d  de79080386c4c5c3  currencyservice
# 1  21:24  46d5d1e1fc25a09db4a81d4d105cee3d  433c41ba31b519dd  frontendservice
# 2  21:24  46d5d1e1fc25a09db4a81d4d105cee3d  28de2c1a557175ec  frontendservice
# 3  21:24  46d5d1e1fc25a09db4a81d4d105cee3d  a6ccc9fc0e441e5c  currencyservice
# 4  21:24  26e74eeaa91cde16a44883aa36a33007  926d999ebf94ce86  frontendservice
#
#   methodName                             operationName  startTimeMillis  \
# 0    Convert  grpc.hipstershop.CurrencyService/Convert    1705353846065
# 1    Convert       hipstershop.CurrencyService/Convert    1705353846065
# 2    Convert       hipstershop.CurrencyService/Convert    1705353846069
# 3    Convert  grpc.hipstershop.CurrencyService/Convert    1705353846071
# 4        NaN                                  frontend    1705353846073
#
#           startTime  duration  statusCode      parentSpanID
# 0  1705353846065999       186         0.0  433c41ba31b519dd
# 1  1705353846065431      4133         0.0  6de46372468bc931
# 2  1705353846069657      3587         0.0  6de46372468bc931
# 3  1705353846071000       134         0.0  28de2c1a557175ec
# 4  1705353846073074    222894         NaN               NaN

# %% [markdown]
# ## Root Cause Analysis

# %%
# preprocess data
metrics = metrics.loc[:, ~metrics.columns.str.endswith("_latency-50")]
metrics = metrics.replace([np.inf, -np.inf], np.nan)

# %%
mmdata = {
    "metric": metrics,
    "logs": logs,
    "logts": log_ts,
    "traces": traces,
    "tracets_lat": trace_ts_lat,
    "tracets_err": trace_ts_err,
    "cluster_info": None
}

output = mmbaro(mmdata, inject_time)
ranks = output["ranks"]
print(ranks[:5])
# Out:
# ['redis_mem', 'redis_diskio', 'checkoutservice_cpu', 'checkoutservice_mem', 'cartservice_latency-90']
